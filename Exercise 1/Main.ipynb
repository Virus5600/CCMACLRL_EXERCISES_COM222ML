# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Functions

# %%
def name():
    print("Karl Satchi Navida")

# %%
name()
# Out:
# Karl Satchi Navida

# %% [markdown]
# ## PANDAS
#
# Pandas library test

# %%
# %pip install pandas
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/matplotlib/
# ERROR: Could not find a version that satisfies the requirement matplotlib (from versions: none)
# ERROR: No matching distribution found for matplotlib

# %%
import pandas as pd

df = pd.read_excel("resource/Exercise.xlsx")
print(df.describe)
# Out:
# <bound method NDFrame.describe of         Name  Age  Weight (kg)
# 0  Subject 1   10           45
# 1  Subject 2   14           63
# 2  Subject 3   20           79
# 3  Subject 4   22           79
# 4  Subject 5   15           25
# 5  Subject 3   20           79>
# Index(['Name', 'Age', 'Weight (kg)'], dtype='object')

# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 270.5 kB/s eta 0:00:28
#    -- ------------------------------------- 0.5/7.8 MB 270.5 kB/s eta 0:00:28
# ...

# %%
import matplotlib.pyplot as plt;

dataset = dict({
    "x": df[["Age"]].to_numpy(),
    "y": df[["Weight (kg)"]].to_numpy()
})

plt.scatter(dataset["x"], dataset["y"])
plt.show()
